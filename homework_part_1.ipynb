# %%
import json
import re
url="https://www.youtube.com/feed/trending"
import requests
response = requests.get(url)
from BeautifulSoup import *

# %%
my_page= response.text
soup=BeautifulSoup(my_page)
tags=soup.findAll('a', attrs={'class':"yt-uix-tile-link yt-ui-ellipsis yt-ui-ellipsis-2 yt-uix-sessionlink      spf-link "})
duration = soup.findAll('span', attrs={'class': 'video-time'})
username = soup.findAll('a', attrs={'class': 'g-hovercard yt-uix-sessionlink       spf-link '})
data = soup.findAll("ul", attrs={ 'class':"yt-lockup-meta-info", } ) 
string=str(data)
views=re.findall('>([0-9]+\S*)\s+views',string)
list1=[]
for i,j,z,x in zip(tags,duration,username,views):
    list1.append({'Title' :i.get("title"),"URL" : "https://www.youtube.com"+i.get('href'),'Duration':j.text,"Username":z.text,"Views": x})
print(list1)

with open('trendingmovies.json', 'w') as output:
    json.dump(list1, output, sort_keys = True, indent = 4)




import unicodecsv as csv

with open('trendingmovies__.csv', 'w') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(["Title", "URL", "Username", "Duration", "Views"])
    for i in list1:
        writer.writerow([i['Title'],i['URL'],i['Username'],i['Duration'],i['Views']])
# Out:
# [{'URL': u'https://www.youtube.com/watch?v=DeAw6aXHzcY', 'Duration': u'1:36', 'Username': u'Adult Swim', 'Views': '2,403,135', 'Title': u'Rick and Morty Season 3 Trailer | Rick and Morty | Adult Swim'}, {'URL': u'https://www.youtube.com/watch?v=2QKg5SZ_35I', 'Duration': u'2:46', 'Username': u'Sony Pictures Entertainment', 'Views': '3,715,804', 'Title': u'JUMANJI: WELCOME TO THE JUNGLE - Official Trailer (HD)'}, {'URL': u'https://www.youtube.com/watch?v=1sYF1SXcWqQ', 'Duration': u'1:57', 'Username': u'Marvel Entertainment', 'Views': '3,826,181', 'Title': u"Marvel's Inhumans - Official Trailer 1"}, {'URL': u'https://www.youtube.com/watch?v=kFQUlA-G0N4', 'Duration': u'18:41', 'Username': u'CinemaSins', 'Views': '1,807,954', 'Title': u'Everything Wrong With Despicable Me 2 In 16 Minutes Or Less'}, {'URL': u'https://www.youtube.com/watch?v=L7YrTk-Y0a0', 'Duration': u'8:46', 'Username': u'Conagh Kathleen', 'Views': '61,929', 'Title': u"Stephen: 'This Is What's Wrong With The American Presi
# ...

# %%
from pprint import pprint
with open('trendingmovies.json') as json_data:
    new_file = json.load(json_data)
pprint(new_file)
# Out:
# [{u'Duration': u'1:36',
#   u'Title': u'Rick and Morty Season 3 Trailer | Rick and Morty | Adult Swim',
#   u'URL': u'https://www.youtube.com/watch?v=DeAw6aXHzcY',
#   u'Username': u'Adult Swim',
#   u'Views': u'2,403,135'},
#  {u'Duration': u'2:46',
#   u'Title': u'JUMANJI: WELCOME TO THE JUNGLE - Official Trailer (HD)',
#   u'URL': u'https://www.youtube.com/watch?v=2QKg5SZ_35I',
#   u'Username': u'Sony Pictures Entertainment',
#   u'Views': u'3,715,804'},
#  {u'Duration': u'1:57',
#   u'Title': u"Marvel's Inhumans - Official Trailer 1",
#   u'URL': u'https://www.youtube.com/watch?v=1sYF1SXcWqQ',
#   u'Username': u'Marvel Entertainment',
#   u'Views': u'3,826,181'},
#  {u'Duration': u'18:41',
#   u'Title': u'Everything Wrong With Despicable Me 2 In 16 Minutes Or Less',
#   u'URL': u'https://www.youtube.com/watch?v=kFQUlA-G0N4',
#   u'Username': u'CinemaSins',
#   u'Views': u'1,807,954'},
#  {u'Duration': u'8:46',
# ...
